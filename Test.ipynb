# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
import glob
import re

# %%
csv_files = glob.glob('INSERT FOLDER*')
csv_files
# Out:
# ['C:/Users/Jared/Desktop/SC1015/Assignment/archive\\action.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\adventure.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\crime.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\family.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\fantasy.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\film-noir.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\history.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\horror.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\mystery.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\scifi.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\sports.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\thriller.csv',
#  'C:/Users/Jared/Desktop/SC1015/Assignment/archive\\war.csv']

# %%
df_csv_concat = pd.concat([pd.read_csv(file) for file in csv_files ], ignore_index=True)
df_csv_concat
# Out:
#           movie_id                         movie_name  year certificate  \
# 0        tt9114286     Black Panther: Wakanda Forever  2022       PG-13
# 1        tt1630029           Avatar: The Way of Water  2022       PG-13
# 2        tt5884796                              Plane  2023           R
# 3        tt6710474  Everything Everywhere All at Once  2022           R
# 4        tt5433140                             Fast X  2023         NaN
# ...            ...                                ...   ...         ...
# 298970  tt26698087                          Janissary   NaN         NaN
# 298971  tt26690183                World War 1 project   NaN         NaN
# 298972  tt26695367                                 74   NaN         NaN
# 298973  tt26698193                     Pandora Palace  2019         NaN
# 298974  tt26733697   Spion 11: Operasjon Traelandsfos  2001         NaN
#
#         runtime                       genre  rating  \
# ...

# %%
df_csv_concat.head()
# Out:
#     movie_id                         movie_name  year certificate  runtime  \
# 0  tt9114286     Black Panther: Wakanda Forever  2022       PG-13  161 min
# 1  tt1630029           Avatar: The Way of Water  2022       PG-13  192 min
# 2  tt5884796                              Plane  2023           R  107 min
# 3  tt6710474  Everything Everywhere All at Once  2022           R  139 min
# 4  tt5433140                             Fast X  2023         NaN      NaN
#
#                         genre  rating  \
# 0    Action, Adventure, Drama     6.9
# 1  Action, Adventure, Fantasy     7.8
# 2            Action, Thriller     6.5
# 3   Action, Adventure, Comedy     8.0
# 4      Action, Crime, Mystery     NaN
#
#                                          description  \
# 0  The people of Wakanda fight to protect their h...
# 1  Jake Sully lives with his newfound family form...
# 2  A pilot finds himself caught in a war zone aft...
# 3  A middle-aged Chinese immigrant is swept up in...
# ...

# %%
print("Number of movies :", len(df_csv_concat["movie_name"].unique()))
# Out:
# Number of Generations : 174858

# %%
movie_dataframe = df_csv_concat.drop_duplicates(subset=["movie_name"])
movie_dataframe
# Out:
#           movie_id                         movie_name  year certificate  \
# 0        tt9114286     Black Panther: Wakanda Forever  2022       PG-13
# 1        tt1630029           Avatar: The Way of Water  2022       PG-13
# 2        tt5884796                              Plane  2023           R
# 3        tt6710474  Everything Everywhere All at Once  2022           R
# 4        tt5433140                             Fast X  2023         NaN
# ...            ...                                ...   ...         ...
# 298966   tt0009655                      Stolen Orders  1918         NaN
# 298969  tt26684378                            Dalilah   NaN         NaN
# 298971  tt26690183                World War 1 project   NaN         NaN
# 298972  tt26695367                                 74   NaN         NaN
# 298974  tt26733697   Spion 11: Operasjon Traelandsfos  2001         NaN
#
#         runtime                       genre  rating  \
# ...

# %%
movie_clean = movie_dataframe.dropna(subset=["year", "director", "star", "movie_name"])
movie_clean = movie_clean.drop(columns=["certificate", "director_id", "star_id", "votes", "gross(in $)"])
movie_clean
# Out:
#           movie_id                         movie_name  year  runtime  \
# 0        tt9114286     Black Panther: Wakanda Forever  2022  161 min
# 1        tt1630029           Avatar: The Way of Water  2022  192 min
# 2        tt5884796                              Plane  2023  107 min
# 3        tt6710474  Everything Everywhere All at Once  2022  139 min
# 4        tt5433140                             Fast X  2023      NaN
# ...            ...                                ...   ...      ...
# 298963   tt0351402                  Na dorogakh voyny  1959      NaN
# 298964   tt0257609         Together in Life and Death  1964   96 min
# 298965   tt5033220                  Opération Maillot  2015      NaN
# 298966   tt0009655                      Stolen Orders  1918   80 min
# 298974  tt26733697   Spion 11: Operasjon Traelandsfos  2001   75 min
#
#                              genre  rating  \
# 0         Action, Adventure, Drama     6.9
# 1       Action, Adventure, Fantasy     7.8
# ...

# %%
movie_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133545 entries, 0 to 298974
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   movie_id     133545 non-null  object
#  1   movie_name   133545 non-null  object
#  2   year         133545 non-null  object
#  3   runtime      109281 non-null  object
#  4   genre        133545 non-null  object
#  5   rating       98394 non-null   float64
#  6   description  133545 non-null  object
#  7   director     133545 non-null  object
#  8   star         133545 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 10.2+ MB

# %%
test = movie_clean['runtime'].str.replace(' min', '')
test
# Out:
# 0         161
# 1         192
# 2         107
# 3         139
# 4         NaN
#          ...
# 298963    NaN
# 298964     96
# 298965    NaN
# 298966     80
# 298974     75
# Name: runtime, Length: 133545, dtype: object

# %%
test.head()
# Out:
# 0    161
# 1    192
# 2    107
# 3    139
# 4      0
# Name: runtime, dtype: object

# %%
test = test.str.replace(",", "").astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 test = test.str.replace(",", "").astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
test = test.fillna(0)

# %%
test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 133545 entries, 0 to 298974
# Series name: runtime
# Non-Null Count   Dtype
# --------------   -----
# 133545 non-null  object
# dtypes: object(1)
# memory usage: 6.1+ MB
